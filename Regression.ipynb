# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
#loading the data from csv file to pandas dataframe
car_dataset = pd.read_csv('/content/cars.csv')

# %%
#inspecting the first 5 rows of the dataframe
car_dataset.head()
# Out:
#                        name  year  ...  transmission         owner
# 0             Maruti 800 AC  2007  ...        Manual   First Owner
# 1  Maruti Wagon R LXI Minor  2007  ...        Manual   First Owner
# 2      Hyundai Verna 1.6 SX  2012  ...        Manual   First Owner
# 3    Datsun RediGO T Option  2017  ...        Manual   First Owner
# 4     Honda Amaze VX i-DTEC  2014  ...        Manual  Second Owner
#
# [5 rows x 8 columns]

# %%
#checking the number of rows and column
car_dataset.shape
# Out:
# (4340, 8)

# %%
#getting some info about the dataset
car_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
#checking the number of missing values
car_dataset.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
#checking the distribution or categorica data
print(car_dataset.fuel.value_counts())
print(car_dataset.seller_type.value_counts())
print(car_dataset.transmission.value_counts())
# Out:
# fuel
# 1    2153
# 0    2123
# 2      40
# 3      23
# 4       1
# Name: count, dtype: int64
# seller_type
# 0    3244
# 1     994
# 2     102
# Name: count, dtype: int64
# transmission
# 0    3892
# 1     448
# Name: count, dtype: int64

# %%
#enclosing "Fuel_Tyoe" Column
car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)

#enclosing "Seller_Type" Column
car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)

#enclosing "Transmission" Column
car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

#enclosing "Owner" Column
car_dataset.replace({'owner':{'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':3,'Test Drive Car':4}},inplace=True)
# Out:
# /tmp/ipykernel_853/1933060120.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'fuel':{'Petrol':0,'Diesel':1,'CNG':2,'LPG':3,'Electric':4}},inplace=True)
# /tmp/ipykernel_853/1933060120.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'seller_type':{'Dealer':0,'Individual':1,'Trustmark Dealer':2}},inplace=True)
# /tmp/ipykernel_853/1933060120.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)
# /tmp/ipykernel_853/1933060120.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'owner':{'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':3,'Test Drive Car':4}},inplace=True)

# %%
car_dataset.head()
# Out:
#                        name  year  ...  transmission  owner
# 0             Maruti 800 AC  2007  ...             0      0
# 1  Maruti Wagon R LXI Minor  2007  ...             0      0
# 2      Hyundai Verna 1.6 SX  2012  ...             0      0
# 3    Datsun RediGO T Option  2017  ...             0      0
# 4     Honda Amaze VX i-DTEC  2014  ...             0      1
#
# [5 rows x 8 columns]

# %%
X = car_dataset.drop(['name', 'selling_price'], axis=1)
Y = car_dataset['selling_price']
print(X)
print(Y)
# Out:
#       year  km_driven  fuel  seller_type  transmission  owner
# 0     2007      70000     0            1             0      0
# 1     2007      50000     0            1             0      0
# 2     2012     100000     1            1             0      0
# 3     2017      46000     0            1             0      0
# 4     2014     141000     1            1             0      1
# ...    ...        ...   ...          ...           ...    ...
# 4335  2014      80000     1            1             0      1
# 4336  2014      80000     1            1             0      1
# 4337  2009      83000     0            1             0      1
# 4338  2016      90000     1            1             0      0
# 4339  2016      40000     0            1             0      0
#
# [4340 rows x 6 columns]
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=2)

# %%
#loading the linear regression model
lin_reg_model = LinearRegression()

# %%
lin_reg_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#prediction on training data
training_data_prediction = lin_reg_model.predict(X_train)

# %%
# R sqaured Error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.42763612850186783

# %%
plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
#prediction on training
test_data_prediction = lin_reg_model.predict(X_test)

# %%
#R squared error
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.5027999353753417

# %%
plt.scatter(Y_test, test_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()
